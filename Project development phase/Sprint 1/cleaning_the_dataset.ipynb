# %% [markdown]
# Cleaning the data set
# Team members:
# 1sowmya s s
# 2shrinithi v
# 3vijayalakshmi n

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_set=pd.read_csv('train.csv')

# %%
missing_values_count = data_set.isnull().sum()

# %%
missing_values_count[0:10]
# Out:
# id                0
# car_name          0
# yr_mfr            0
# fuel_type         0
# kms_run           0
# sale_price        0
# city              0
# times_viewed      0
# body_type        90
# transmission    474
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(data_set.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 2.123248424232953

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = data_set.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#    id           car_name  yr_mfr fuel_type  kms_run  sale_price   city  \
# 0   1       maruti swift    2015    petrol     8063      386399  noida
# 1   2    maruti alto 800    2016    petrol    23104      265499  noida
# 2   3  hyundai grand i10    2017    petrol    23402      477699  noida
# 3   4       maruti swift    2013    diesel    39124      307999  noida
# 4   5  hyundai grand i10    2015    petrol    22116      361499  noida
#
#    times_viewed          variant  assured_buy  is_hot   rto     make  \
# 0         18715          lxi opt         True    True  dl6c   maruti
# 1          2676              lxi         True    True  up16   maruti
# 2           609  sports 1.2 vtvt         True    True  up80  hyundai
# 3          6511              vdi         True    True  dl1c   maruti
# 4          3225   magna 1.2 vtvt        False    True  dl12  hyundai
#
#        model  total_owners  broker_quote  emi_starts_from  booking_down_pymnt  \
# 0      swift             2        397677             8975               57960
# 1   alto 800             1        272935             6167               39825
# 2  grand i10             1        469605            11096               71655
# 3      swift             1        294262             7154               46200
# 4  grand i10             1        360716             8397               54225
#
#    reserved  warranty_avail
# 0     False           False
# 1     False           False
# 2     False           False
# 3     False           False
# 4     False           False

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % data_set.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 30
#
# Columns with na's dropped: 20

# %%
# get a small subset of the NFL dataset
subset_nfl_data = data_set.head()
subset_nfl_data
# Out:
#    id           car_name  yr_mfr fuel_type  kms_run  sale_price   city  \
# 0   1       maruti swift    2015    petrol     8063      386399  noida
# 1   2    maruti alto 800    2016    petrol    23104      265499  noida
# 2   3  hyundai grand i10    2017    petrol    23402      477699  noida
# 3   4       maruti swift    2013    diesel    39124      307999  noida
# 4   5  hyundai grand i10    2015    petrol    22116      361499  noida
#
#    times_viewed  body_type transmission  ... total_owners  broker_quote  \
# 0         18715  hatchback       manual  ...            2        397677
# 1          2676  hatchback       manual  ...            1        272935
# 2           609  hatchback       manual  ...            1        469605
# 3          6511  hatchback       manual  ...            1        294262
# 4          3225  hatchback       manual  ...            1        360716
#
#   original_price car_rating            ad_created_on fitness_certificate  \
# 0       404177.0      great  2021-04-04T07:09:18.583                True
# 1       354313.0      great  2021-03-22T14:07:32.833                True
# 2            NaN      great  2021-03-20T05:36:31.311                True
# 3       374326.0      great  2021-01-21T12:59:19.299                True
# 4       367216.0      great  2021-04-01T13:33:40.733                True
#
#   emi_starts_from booking_down_pymnt reserved warranty_avail
# 0            8975              57960    False          False
# 1            6167              39825    False          False
# 2           11096              71655    False          False
# 3            7154              46200    False          False
# 4            8397              54225    False          False
#
# [5 rows x 30 columns]

# %%
# replace all NA's with 0
subset_nfl_data.fillna(0)
# Out:
#    id           car_name  yr_mfr fuel_type  kms_run  sale_price   city  \
# 0   1       maruti swift    2015    petrol     8063      386399  noida
# 1   2    maruti alto 800    2016    petrol    23104      265499  noida
# 2   3  hyundai grand i10    2017    petrol    23402      477699  noida
# 3   4       maruti swift    2013    diesel    39124      307999  noida
# 4   5  hyundai grand i10    2015    petrol    22116      361499  noida
#
#    times_viewed  body_type transmission  ... total_owners  broker_quote  \
# 0         18715  hatchback       manual  ...            2        397677
# 1          2676  hatchback       manual  ...            1        272935
# 2           609  hatchback       manual  ...            1        469605
# 3          6511  hatchback       manual  ...            1        294262
# 4          3225  hatchback       manual  ...            1        360716
#
#   original_price car_rating            ad_created_on fitness_certificate  \
# 0       404177.0      great  2021-04-04T07:09:18.583                True
# 1       354313.0      great  2021-03-22T14:07:32.833                True
# 2            0.0      great  2021-03-20T05:36:31.311                True
# 3       374326.0      great  2021-01-21T12:59:19.299                True
# 4       367216.0      great  2021-04-01T13:33:40.733                True
#
#   emi_starts_from booking_down_pymnt reserved warranty_avail
# 0            8975              57960    False          False
# 1            6167              39825    False          False
# 2           11096              71655    False          False
# 3            7154              46200    False          False
# 4            8397              54225    False          False
#
# [5 rows x 30 columns]
